# %%
from numpy import arange, pi, sin, cos, arccos
n = 100
goldenRatio = (1 + 5**0.5)/2
i = arange(0, n)
phi = 2 *pi * i / goldenRatio
theta = arccos(1 - 2*(i+0.5)/n)
x, y, z = cos(phi) * sin(theta), sin(phi) * sin(theta), cos(theta);

# %%
import plotly.graph_objects as go
grid_marker_style = dict(color='black', size=4)
sphere_horizontal = go.Scatter3d(x=x, y=y, z=z, mode='markers',
                            opacity=0.5, name='grid', marker=grid_marker_style)

# %%
fig = go.Figure(data=[sphere_horizontal])
fig.show()
# Out:
# <div>                            <div id="06f29f66-a1ee-42af-b8c6-48bd7345103c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06f29f66-a1ee-42af-b8c6-48bd7345103c")) {                    Plotly.newPlot(                        "06f29f66-a1ee-42af-b8c6-48bd7345103c",                        [{"marker":{"color":"black","size":4},"mode":"markers","name":"grid","opacity":0.5,"x":[0.1410673597966589,-0.17925799888815627,0.027298673793297628,0.223637495076081,-0.4082703337484341,0.384719106862696,-0.1279983494209809,-0.2427978412318791,0.5239190311901128,-0.5420638502883903,0.2598628796193766,0.1909562397791463,-0.5722834231380938,0.6675062690706624,-0.4050071077206252,-0.09301724105770713,0.5676456679421027,-0.7592852649071572,0.5504734730017861,-0.03660
# ...

# %%
theta.shape
# Out:
# (100,)
